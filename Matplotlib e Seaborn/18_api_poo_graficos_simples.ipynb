# %% [markdown]
# # Trabalhando com eixos

# %% [markdown]
# ## Gráfico de linhas

# %%
import matplotlib.pyplot as plt

meses = ['Jan', 'Fev', 'Mar', 'Abr', 'Mai', 'Jun', 'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez']
vendas = [85, 90, 78, 92, 88, 96, 94, 98, 100, 102, 105, 108]
fig, ax = plt.subplots()  # Cria a figura e os eixos
ax.set_ylabel('Mês') # Adiciona o rótulo do eixo y
ax.set_xlabel('Vendas') # Adiciona o rótulo do eixo x   
ax.set_title('Vendas ao longo do ano') # Adiciona o título do gráfico   

plt.show() # Exibe o gráfico

# %% [markdown]
# ## Gráfico de barras

# %%
import matplotlib.pyplot as plt

produtos = ['Produto A', 'Produto B', 'Produto C', 'Produto D', 'Produto E']
quantidades = [23, 45, 17, 30, 37]

fig, ax = plt.subplots()  # Cria a figura e os eixos    

ax.bar(produtos, quantidades) # Cria o gráfico de barras    
ax.set_ylabel('Produto') # Adiciona o rótulo do eixo y
ax.set_xlabel('Quantidade de vendas') # Adiciona o rótulo do eixo x   
ax.set_title('quantidade de vendas por produto') # Adiciona o título do gráfico
# Out:
# Text(0.5, 1.0, 'quantidade de vendas por produto')

# %% [markdown]
# ## Gráfico de pizza

# %%
categorias = ['Eletrônicos', 'Roupas', 'Alimentos', 'Livros']
quantidades = [45, 30, 15, 10]
destaque = [0.1, 0, 0, 0]  # destacar a primeira fatia

fig, ax = plt.subplots()  # Cria a figura e os eixos    

ax.pie(quantidades, explode=destaque, labels=categorias, autopct='%1.1f%%') # Cria o gráfico de pizza 

plt.show() # Exibe o gráfico

# %% [markdown]
# ## Gráfico de barras empilhadas

# %%
anos = [2018, 2019, 2020, 2021]
vendas_online = [5, 10, 15, 20]
vendas_loja = [10, 8, 6, 4]

fig, ax = plt.subplots()  # Cria a figura e os eixos    
ax.bar(anos, vendas_online, label='online') # Cria o primeiro conjunto de barras
ax.bar(anos, vendas_loja, bottom=vendas_online, label='Loja') # Adiciona o segundo conjunto de barras
ax.set_ylabel('Vendas') # Adiciona o rótulo do eixo y   
ax.set_xlabel('ano')  # Adiciona o rótulo do eixo x
ax.set_title('Vendas online vs Lojas') # Adiciona o título do gráfico 
ax.set_xticks(anos) # Adiciona os anos no eixo x    
ax.legend() # Adiciona a legenda    
plt.show()
