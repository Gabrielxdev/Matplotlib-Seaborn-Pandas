# %% [markdown]
# # Temas do Seaborn

# %%
import seaborn as sns

meses = ['Jan', 'Fev', 'Mar', 'Abr', 'Mai', 'Jun', 'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez']
vendas = [85, 90, 78, 92, 88, 96, 94, 98, 100, 102, 105, 108]

dados = {'Meses': meses, 'Vendas': vendas}

sns.lineplot(x='Meses', y='Vendas', data=dados);

# %% [markdown]
# No Seaborn, um tema é a combinação de estilo, contexto e paleta de cores que juntos definem a aparência de um gráfico.

# %% [markdown]
# https://seaborn.pydata.org/generated/seaborn.set_theme.html
#
# https://seaborn.pydata.org/tutorial/aesthetics.html
#
# https://seaborn.pydata.org/generated/seaborn.color_palette.html#seaborn.color_palette
#
# https://seaborn.pydata.org/tutorial/color_palettes.html

# %%
estilos = ['darkgrid', 'whitegrid', 'dark', 'white', 'ticks']
contextos = ['paper', 'notebook', 'talk', 'poster']
paletas = ['deep', 'muted', 'bright', 'pastel', 'dark', 'colorblind']  # além das do matplotlib

# %%
sns.set_theme()

sns.lineplot(x='Meses', y='Vendas', data=dados);

# %%
sns.set_theme(style='darkgrid', context='notebook', palette='colorblind')     
sns.lineplot(x='Meses', y='Vendas', data=dados);

# %%
sns.set_theme()

cidades = ['São Paulo', 'Rio de Janeiro', 'Belo Horizonte', 'Porto Alegre', 'Salvador']
temperaturas = [30, 32, 28, 22, 33]

barras = sns.barplot(x=cidades, y=temperaturas)
barras.set_title('Temperatura média nas capitais')
barras.set_ylabel('Temperatura (°C)');

# %%
sns.set_theme(palette='Set2', style='whitegrid', context='notebook')    

cidades = ['São Paulo', 'Rio de Janeiro', 'Belo Horizonte', 'Porto Alegre', 'Salvador']
temperaturas = [30, 32, 28, 22, 33]

barras = sns.barplot(x=cidades, y=temperaturas)
barras.set_title('Temperatura média nas capitais')
barras.set_ylabel('Temperatura (°C)');
