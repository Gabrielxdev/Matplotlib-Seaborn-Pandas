# %% [markdown]
# ## Criando Seu Próprio Estilo
#
# Embora o Matplotlib venha com uma variedade de estilos pré-prontos, você também pode criar e usar seu próprio estilo personalizado. Isso pode ser útil se você quiser que seus gráficos tenham uma aparência específica que não é fornecida por nenhum dos estilos pré-prontos.
#
# Para criar seu próprio estilo, você precisa criar um arquivo de configuração que define as configurações de estilo que você deseja usar. Este arquivo deve ser um arquivo `.mplstyle`, que é basicamente um arquivo de texto que contém uma série de configurações no formato `chave: valor`.
#
# Por exemplo, aqui está um exemplo de um arquivo de estilo que define algumas configurações básicas:
#
# ```
# axes.titlesize : 24
# axes.labelsize : 20
# xtick.labelsize : 16
# ytick.labelsize : 16
# ```
#
# Este arquivo define o tamanho do título e do rótulo dos eixos, a largura da linha, o tamanho do marcador e o tamanho do rótulo do tick.

# %%
import matplotlib.pyplot as plt

produtos = ['Produto A', 'Produto B', 'Produto C', 'Produto D', 'Produto E']
quantidades = [23, 45, 17, 30, 37]

barras = plt.barh(produtos, quantidades)

plt.bar_label(barras, labels=quantidades, padding=3, fontsize=10, fontweight='bold')

plt.xticks([])
plt.title('Quantidade de Produtos Vendidos')
plt.grid(False)

plt.show()

# %%
import matplotlib.pyplot as plt

plt.style.use('meu_estilo_1.mplstyle')

produtos = ['Produto A', 'Produto B', 'Produto C', 'Produto D', 'Produto E']
quantidades = [23, 45, 17, 30, 37]

barras = plt.barh(produtos, quantidades)

plt.bar_label(barras, labels=quantidades, padding=3, fontsize=10, fontweight='bold')

plt.xticks([])
plt.yticks(fontsize=12, fontweight='bold')
plt.title('Quantidade de Produtos Vendidos')
plt.grid(False)

plt.show()

# %% [markdown]
# Referência da estrutura do arquivo: https://matplotlib.org/stable/tutorials/introductory/customizing.html#the-matplotlibrc-file

# %% [markdown]
# Roda de cores para referência: https://color.adobe.com/pt/create/color-wheel

# %%
import matplotlib as mpl    

print(mpl.matplotlib_fname())   # Exibe o caminho do arquivo de configuração do Matplotlib
# Out:
# c:\Users\leuci\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\mpl-data\matplotlibrc

# %%
import matplotlib.pyplot as plt

plt.style.use('meu_estilo_2.mplstyle')

produtos = ['Produto A', 'Produto B', 'Produto C', 'Produto D', 'Produto E']
quantidades = [23, 45, 17, 30, 37]

barras = plt.barh(produtos, quantidades)

plt.bar_label(barras, labels=quantidades, padding=3, fontsize=10, fontweight='bold')

plt.xticks([])
plt.yticks(fontsize=12, fontweight='bold')
plt.title('Quantidade de Produtos Vendidos')
plt.grid(False)

plt.show()

# %%
import matplotlib.pyplot as plt

plt.style.use('meu_estilo_3.mplstyle')

produtos = ['Produto A', 'Produto B', 'Produto C', 'Produto D', 'Produto E']
quantidades = [23, 45, 17, 30, 37]

barras = plt.barh(produtos, quantidades)

plt.bar_label(barras, labels=quantidades, padding=3, fontsize=10, fontweight='bold')

barras[1].set_color('C2')  
plt.xticks([])
plt.title('Quantidade de Produtos Vendidos')
plt.grid(False)

plt.show()
# Out:
# Bad value in file 'meu_estilo_3.mplstyle', line 11 ("axes.prop_cycle: cycler('color', ['2341FC', '5A36FF', '962BFC', '3F95FC', 'D60DFC'. '8F7AE1'])"): Key axes.prop_cycle: "cycler('color', ['2341FC', '5A36FF', '962BFC', '3F95FC', 'D60DFC'. '8F7AE1'])" is not a valid cycler construction: invalid syntax (<unknown>, line 1)

# %%
import matplotlib.pyplot as plt

plt.style.use('meu_estilo_3.mplstyle')

produtos = ['Produto A', 'Produto B', 'Produto C', 'Produto D', 'Produto E']
quantidades = [23, 45, 17, 30, 37]

barras = plt.barh(produtos, quantidades)

plt.bar_label(barras, labels=quantidades, padding=3, fontsize=10, fontweight='bold')

barras[1].set_color('C2')  
plt.xticks([])
plt.title('Quantidade de Produtos Vendidos')
plt.grid(False)

plt.show()
